# %%
import pandas as pd

url = "https://www.basketball-reference.com/draft/"

# read ALL draft years in one call
tables = pd.read_html(url)

df = tables[0]  # first table = full draft history

# inspect columns
print(df.columns)

# save immediately
df.to_csv("nba_draft_all_years.csv", index=False)

df.head(), df.tail()
# Out:
# Index(['Draft', 'Lg', 'Team', 'Player', 'College'], dtype='object')
# (   Draft   Lg               Team              Player         College
#  0   2025  NBA   Dallas Mavericks        Cooper Flagg            Duke
#  1   2024  NBA      Atlanta Hawks  Zaccharie Risacher             NaN
#  2   2023  NBA  San Antonio Spurs   Victor Wembanyama             NaN
#  3   2022  NBA      Orlando Magic      Paolo Banchero            Duke
#  4   2021  NBA    Detroit Pistons     Cade Cunningham  Oklahoma State,
#      Draft   Lg                     Team           Player  \
#  74   1951  NBA        Baltimore Bullets  Gene Melchiorre
#  75   1950  NBA           Boston Celtics      Chuck Share
#  76   1949  BAA  Providence Steamrollers    Howie Shannon
#  77   1948  BAA  Providence Steamrollers   Andy Tonkovich
#  78   1947  BAA       Pittsburgh Ironmen  Clifton McNeely
#
#                        College
#  74                    Bradley
#  75              Bowling Green
#  76               Kansas State
#  77                   Marshall
#  78  Texas Wesleyan University  )

# %%
import os
import time
import logging
from typing import Dict, Optional

import pandas as pd

# Try to use cloudscraper if available (helps with Cloudflare)
try:
    import cloudscraper
    scraper = cloudscraper.create_scraper(
        browser={"browser": "chrome", "platform": "windows", "mobile": False}
    )
    USE_CLOUDSCRAPER = True
except ImportError:
    import requests
    scraper = requests.Session()
    USE_CLOUDSCRAPER = False

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

BASE_URL = "https://www.basketball-reference.com/draft/NBA_{}.html"
START_YEAR = 2000
END_YEAR = 2025

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0 Safari/537.36"
    ),
    "Accept-Language": "en-US,en;q=0.9",
}

OUT_DIR = "draft_tables"
os.makedirs(OUT_DIR, exist_ok=True)


def fetch_html(year: int) -> Optional[str]:
    """Fetch raw HTML for one draft year."""
    url = BASE_URL.format(year)
    logging.info(f"Fetching {url}  (cloudscraper={USE_CLOUDSCRAPER})")

    try:
        resp = scraper.get(url, headers=HEADERS, timeout=20)
    except Exception as e:
        logging.error(f"{year}: request failed: {e}")
        return None

    if resp.status_code != 200:
        logging.warning(f"{year}: HTTP {resp.status_code}, skipping.")
        return None

    return resp.text


def parse_draft_table(html: str, year: int) -> Optional[pd.DataFrame]:
    """Parse and lightly clean the main draft table for a single year."""
    try:
        tables = pd.read_html(html)
    except ValueError as e:
        logging.error(f"{year}: pandas.read_html failed: {e}")
        return None

    if not tables:
        logging.warning(f"{year}: no tables found")
        return None

    # On these pages, the first table is the full draft
    df = tables[0].copy()

    # Drop completely empty columns (from multi-level headers etc.)
    df = df.dropna(axis=1, how="all")

    # Remove repeated header rows that appear inside the body
    for col in ("Pk", "Rnd"):
        if col in df.columns:
            df = df[df[col] != col]

    # Keep only rows that look like real picks (Pk not NaN and numeric)
    if "Pk" in df.columns:
        df = df[~df["Pk"].isna()]

        def is_int_like(x):
            try:
                int(str(x))
                return True
            except Exception:
                return False

        df = df[df["Pk"].apply(is_int_like)]
        df["Pk"] = df["Pk"].astype(int)

    df["Year"] = year
    df = df.reset_index(drop=True)
    return df


def scrape_each_draft_separately(
    start_year: int = START_YEAR,
    end_year: int = END_YEAR,
) -> Dict[int, pd.DataFrame]:
    """
    Scrape each draft table from start_year to end_year (inclusive).

    Returns:
        dict mapping {year: DataFrame} and saves one CSV per year.
    """
    draft_dfs: Dict[int, pd.DataFrame] = {}

    for year in range(start_year, end_year + 1):
        html = fetch_html(year)
        if html is None:
            continue

        df_year = parse_draft_table(html, year)
        if df_year is None or df_year.empty:
            logging.warning(f"{year}: no usable rows, not saving.")
            continue

        # Save individual CSV
        out_path = os.path.join(OUT_DIR, f"nba_draft_{year}.csv")
        df_year.to_csv(out_path, index=False)
        logging.info(f"{year}: saved {len(df_year)} rows to {out_path}")

        # Store in dict for in-memory use
        draft_dfs[year] = df_year

        # Be polite with a small delay
        time.sleep(1.0)

    return draft_dfs


# ---- run it ----
draft_dfs = scrape_each_draft_separately()

# Quick sanity check: show years successfully scraped
print("Years scraped:", sorted(draft_dfs.keys()))
for y in sorted(draft_dfs.keys())[:3]:   # first 3 years as a preview
    print(f"\n=== {y} draft, first 5 rows ===")
    print(draft_dfs[y].head())
# Out:
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# /tmp/ipython-input-3380566444.py:63: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Years scraped: [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
#
# === 2000 draft, first 5 rows ===
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0         Round 1  \
#                   Rk                 Pk                 Tm          Player
# 0                  1                  1                NJN   Kenyon Martin
# 1                  2                  2                VAN  Stromile Swift
# 2                  3                  3                LAC    Darius Miles
# 3                  4                  4                CHI    Marcus Fizer
# 4                  5                  5                ORL     Mike Miller
#
#               Unnamed: 5_level_0 Totals                      ... Shooting  \
#       College                Yrs      G     MP    PTS   TRB  ...      FT%
# 0  Cincinnati                 15    757  23134   9325  5159  ...     .629
# 1         LSU                  9    547  10804   4582  2535  ...     .699
# 2         NaN                  7    446  11730   4507  2190  ...     .590
# 3  Iowa State                  6    289   6032   2782  1340  ...     .691
# 4     Florida                 17   1032  27812  10973  4376  ...     .769
#
#   Per Game                 Advanced                    Year
#         MP   PTS  TRB  AST       WS WS/48   BPM  VORP
# 0     30.6  12.3  6.8  1.9     48.0  .100   0.1  12.1  2000
# 1     19.8   8.4  4.6  0.5     21.3  .095  -1.6   1.1  2000
# 2     26.3  10.1  4.9  1.9      9.5  .039  -1.0   3.0  2000
# 3     20.9   9.6  4.6  1.2      2.7  .022  -3.7  -2.6  2000
# 4     26.9  10.6  4.2  2.6     60.7  .105   0.8  19.8  2000
#
# [5 rows x 23 columns]
#
# === 2001 draft, first 5 rows ===
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0           Round 1  \
#                   Rk                 Pk                 Tm            Player
# 0                  1                  1                WAS       Kwame Brown
# 1                  2                  2                LAC    Tyson Chandler
# 2                  3                  3                ATL         Pau Gasol
# 3                  4                  4                CHI        Eddy Curry
# 4                  5                  5                GSW  Jason Richardson
#
#                   Unnamed: 5_level_0 Totals                       ...  \
#           College                Yrs      G     MP    PTS    TRB  ...
# 0             NaN                 12    607  13389   4035   3333  ...
# 1             NaN                 19   1160  31617   9509  10467  ...
# 2             NaN                 18   1226  41001  20894  11305  ...
# 3             NaN                 11    527  13109   6820   2725  ...
# 4  Michigan State                 13    857  29241  14644   4245  ...
#
#   Shooting Per Game                 Advanced                    Year
#        FT%       MP   PTS  TRB  AST       WS WS/48   BPM  VORP
# 0     .570     22.1   6.6  5.5  0.9     20.8  .074  -2.4  -1.3  2001
# 1     .644     27.3   8.2  9.0  0.8    102.1  .155   0.1  16.9  2001
# 2     .753     33.4  17.0  9.2  3.2    144.1  .169   3.6  57.5  2001
# 3     .642     24.9  12.9  5.2  0.5     21.7  .080  -2.4  -1.3  2001
# 4     .707     34.1  17.1  5.0  2.7     59.1  .097   1.2  23.8  2001
#
# [5 rows x 23 columns]
#
# === 2002 draft, first 5 rows ===
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                   Rk                 Pk                 Tm
# 0                  1                  1                HOU
# 1                  2                  2                CHI
# 2                  3                  3                GSW
# 3                  4                  4                MEM
# 4                  5                  5                DEN
#
#                 Round 1         Unnamed: 5_level_0 Totals                      \
#                  Player College                Yrs      G     MP    PTS   TRB
# 0              Yao Ming     NaN                  8    486  15818   9247  4494
# 1          Jay Williams    Duke                  1     75   1961    714   195
# 2         Mike Dunleavy    Duke                 15    986  27340  11048  4211
# 3           Drew Gooden  Kansas                 14    790  20127   8653  5618
# 4  Nikoloz Tskitishvili     NaN                  4    172   1946    507   307
#
#    ... Shooting Per Game                 Advanced                     Year
#    ...      FT%       MP   PTS  TRB  AST       WS  WS/48   BPM  VORP
# 0  ...     .833     32.5  19.0  9.2  1.6     65.9   .200   3.2  20.7  2002
# 1  ...     .640     26.1   9.5  2.6  4.7      0.8   .020  -2.0   0.0  2002
# 2  ...     .803     27.7  11.2  4.3  2.2     58.5   .103   0.3  15.7  2002
# 3  ...     .760     25.5  11.0  7.1  1.1     43.9   .105  -1.2   4.3  2002
# 4  ...     .730     11.3   2.9  1.8  0.7     -1.6  -.039  -6.1  -2.0  2002
#
# [5 rows x 23 columns]

# %%
import pandas as pd
import os

folder = "draft_tables"

all_dfs = []

for year in range(2000, 2025 + 1):
    filename = f"nba_draft_{year}.csv"
    path = os.path.join(folder, filename)

    df = pd.read_csv(path)

    # Add Year column (if not already present)
    df["Year"] = year

    all_dfs.append(df)

len(all_dfs)
# Out:
# 26

# %%
for year, df in zip(range(2000, 2026), all_dfs):
    print(year, df.columns.tolist())
# Out:
# 2000 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2001 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2002 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2003 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2004 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2005 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2006 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2007 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2008 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2009 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2010 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2011 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2012 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2013 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2014 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2015 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2016 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2017 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2018 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2019 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2020 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2021 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2022 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2023 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2024 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']
# 2025 ['Unnamed: 0_level_0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Round 1', 'Round 1.1', 'Unnamed: 5_level_0', 'Totals', 'Totals.1', 'Totals.2', 'Totals.3', 'Totals.4', 'Shooting', 'Shooting.1', 'Shooting.2', 'Per Game', 'Per Game.1', 'Per Game.2', 'Per Game.3', 'Advanced', 'Advanced.1', 'Advanced.2', 'Advanced.3', 'Year']

# %%
df.columns = df.columns.str.strip()       # remove spaces
df.columns = df.columns.str.replace(r'\W+', '_', regex=True)  # clean non-alphanumerics
df.columns = df.columns.str.upper()       # normalize casing
rename_map = {
    "PK": "PK",
    "PICK": "PK",
    "ROUND_1_PK": "PK",
    "RK_PK": "PK",
    "P_K": "PK"
}

df = df.rename(columns={c: "PK" for c in df.columns if c in rename_map})

# %%
def flatten_columns(df):
    """
    Properly flatten Basketball-Reference multi-level column headers.
    Removes Unnamed levels and joins real header parts.
    """
    new_cols = []
    for col in df.columns:
        # col is a tuple for MultiIndex (level0, level1, ...)
        parts = [str(c) for c in col if "Unnamed" not in str(c)]
        if len(parts) == 0:
            parts = [""]  # empty fallback
        new_cols.append("_".join(parts).strip("_"))
    df.columns = new_cols
    return df

df = flatten_columns(df)

# %%
import pandas as pd
import requests
import time
import os

BASE_URL = "https://www.basketball-reference.com/draft/NBA_{}.html"
OUT_DIR = "draft_tables_fixed"
os.makedirs(OUT_DIR, exist_ok=True)

headers = {
    "User-Agent": "Mozilla/5.0"
}

def flatten_columns(df):
    """Properly flatten Basketball-Reference multi-level headers."""
    new_cols = []
    for col in df.columns:
        parts = [str(c) for c in col if ("Unnamed" not in str(c))]
        if len(parts) == 0:
            new_cols.append("")
        else:
            new_cols.append("_".join(parts))
    df.columns = new_cols
    return df

def scrape_year(year):
    print(f"Scraping {year}...")
    url = BASE_URL.format(year)
    html = requests.get(url, headers=headers).text

    tables = pd.read_html(html)
    df = tables[0].copy()

    # Flatten headers
    df = flatten_columns(df)

    # Drop empty columns
    df = df.loc[:, df.columns.notnull()]

    # Drop duplicate header rows inside table
    if "Pk" in df.columns:
        df = df[df["Pk"] != "Pk"]

    # Convert Pk to numeric
    if "Pk" in df.columns:
        df["Pk"] = pd.to_numeric(df["Pk"], errors="coerce")

    df["Year"] = year
    df.to_csv(f"{OUT_DIR}/nba_draft_{year}.csv", index=False)
    print(f"Saved nba_draft_{year}.csv")

for year in range(2000, 2026):
    scrape_year(year)
    time.sleep(1)
# Out:
# Scraping 2000...
# Saved nba_draft_2000.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2001...
# Saved nba_draft_2001.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2002...
# Saved nba_draft_2002.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2003...
# Saved nba_draft_2003.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2004...
# Saved nba_draft_2004.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2005...
# Saved nba_draft_2005.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2006...
# Saved nba_draft_2006.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2007...
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Saved nba_draft_2007.csv
# Scraping 2008...
# Saved nba_draft_2008.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2009...
# Saved nba_draft_2009.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2010...
# Saved nba_draft_2010.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2011...
# Saved nba_draft_2011.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2012...
# Saved nba_draft_2012.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2013...
# Saved nba_draft_2013.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2014...
# Saved nba_draft_2014.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2015...
# Saved nba_draft_2015.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2016...
# Saved nba_draft_2016.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2017...
# Saved nba_draft_2017.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2018...
# Saved nba_draft_2018.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2019...
# Saved nba_draft_2019.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2020...
# Saved nba_draft_2020.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2021...
# Saved nba_draft_2021.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2022...
# Saved nba_draft_2022.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2023...
# Saved nba_draft_2023.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2024...
# Saved nba_draft_2024.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# Scraping 2025...
# Saved nba_draft_2025.csv
# /tmp/ipython-input-1438856590.py:31: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)

# %%
import os

filename = "nba_draft_2000.csv"
for root, dirs, files in os.walk("/", topdown=True):
    if filename in files:
        print(os.path.join(root, filename))
        break
# Out:
# /content/draft_tables_fixed/nba_draft_2000.csv

# %%
import pandas as pd
import os

folder = "draft_tables_fixed"
dfs = []

for year in range(2000, 2026):
    df = pd.read_csv(os.path.join(folder, f"nba_draft_{year}.csv"))
    dfs.append(df)

df_all = pd.concat(dfs, ignore_index=True)

# Sorting now works because 'Pk' finally exists
df_all = df_all.sort_values(["Year", "Pk"]).reset_index(drop=True)

df_all.to_csv("nba_draft_2000_2025_all.csv", index=False)

df_all.head()
# Out:
#     Rk   Pk   Tm  Round 1_Player Round 1_College   Yrs Totals_G Totals_MP  \
# 0  1.0  1.0  NJN   Kenyon Martin      Cincinnati  15.0      757     23134
# 1  2.0  2.0  VAN  Stromile Swift             LSU   9.0      547     10804
# 2  3.0  3.0  LAC    Darius Miles             NaN   7.0      446     11730
# 3  4.0  4.0  CHI    Marcus Fizer      Iowa State   6.0      289      6032
# 4  5.0  5.0  ORL     Mike Miller         Florida  17.0     1032     27812
#
#   Totals_PTS Totals_TRB  ... Shooting_FT% Per Game_MP Per Game_PTS  \
# 0       9325       5159  ...         .629        30.6         12.3
# 1       4582       2535  ...         .699        19.8          8.4
# 2       4507       2190  ...         .590        26.3         10.1
# 3       2782       1340  ...         .691        20.9          9.6
# 4      10973       4376  ...         .769        26.9         10.6
#
#   Per Game_TRB Per Game_AST Advanced_WS Advanced_WS/48 Advanced_BPM  \
# 0          6.8          1.9        48.0           .100          0.1
# 1          4.6          0.5        21.3           .095         -1.6
# 2          4.9          1.9         9.5           .039         -1.0
# 3          4.6          1.2         2.7           .022         -3.7
# 4          4.2          2.6        60.7           .105          0.8
#
#   Advanced_VORP  Year
# 0          12.1  2000
# 1           1.1  2000
# 2           3.0  2000
# 3          -2.6  2000
# 4          19.8  2000
#
# [5 rows x 23 columns]

# %%
def strong_flatten(df):
    new_cols = []
    for col in df.columns:
        parts = [str(c) for c in col.split("_") if "Unnamed" not in c and c != ""]
        if len(parts) == 0:
            new_cols.append("COL")
        else:
            new_cols.append("_".join(parts))
    df.columns = new_cols
    return df

# %%
def clean_columns(df):
    clean = []
    for c in df.columns:
        c = str(c)
        c = c.replace(" ", "_")          # replace spaces
        c = c.replace("__", "_")         # collapse double underscores
        c = c.replace("Round_1_", "")    # remove extra hierarchy
        c = c.replace("Totals_", "")     # keep G, MP, PTS, etc.
        c = c.replace("Shooting_", "")   # Shooting FT% → FT%
        c = c.replace("Per_Game_", "")   # Per Game MP → MP (per-game)
        c = c.replace("Advanced_", "")   # remove advanced prefix
        clean.append(c.strip("_"))
    df.columns = clean
    return df

df_all = clean_columns(df_all)
df_all.head()
# Out:
#     Rk   Pk   Tm          Player     College   Yrs     G     MP    PTS   TRB  \
# 0  1.0  1.0  NJN   Kenyon Martin  Cincinnati  15.0   757  23134   9325  5159
# 1  2.0  2.0  VAN  Stromile Swift         LSU   9.0   547  10804   4582  2535
# 2  3.0  3.0  LAC    Darius Miles         NaN   7.0   446  11730   4507  2190
# 3  4.0  4.0  CHI    Marcus Fizer  Iowa State   6.0   289   6032   2782  1340
# 4  5.0  5.0  ORL     Mike Miller     Florida  17.0  1032  27812  10973  4376
#
#    ...   FT%    MP   PTS  TRB  AST    WS WS/48   BPM  VORP  Year
# 0  ...  .629  30.6  12.3  6.8  1.9  48.0  .100   0.1  12.1  2000
# 1  ...  .699  19.8   8.4  4.6  0.5  21.3  .095  -1.6   1.1  2000
# 2  ...  .590  26.3  10.1  4.9  1.9   9.5  .039  -1.0   3.0  2000
# 3  ...  .691  20.9   9.6  4.6  1.2   2.7  .022  -3.7  -2.6  2000
# 4  ...  .769  26.9  10.6  4.2  2.6  60.7  .105   0.8  19.8  2000
#
# [5 rows x 23 columns]

# %%
# Ensure Year is numeric
df_all["Year"] = pd.to_numeric(df_all["Year"], errors="coerce").astype(int)

# Sort by Year then pick
df_all = df_all.sort_values(["Year", "Pk"]).reset_index(drop=True)

# Save final dataset
df_all.to_csv("nba_draft_2000_2025_clean.csv", index=False)

# Quick sanity checks
print(df_all[["Year", "Pk", "Tm", "Player"]].head(10))   # first 10 picks of 2000
print()
print(df_all[df_all["Year"] == 2001][["Year", "Pk", "Tm", "Player"]].head())  # start of 2001
print()
print(df_all["Year"].min(), df_all["Year"].max(), len(df_all))
# Out:
#    Year    Pk   Tm           Player
# 0  2000   1.0  NJN    Kenyon Martin
# 1  2000   2.0  VAN   Stromile Swift
# 2  2000   3.0  LAC     Darius Miles
# 3  2000   4.0  CHI     Marcus Fizer
# 4  2000   5.0  ORL      Mike Miller
# 5  2000   6.0  ATL  DerMarr Johnson
# 6  2000   7.0  CHI       Chris Mihm
# 7  2000   8.0  CLE   Jamal Crawford
# 8  2000   9.0  HOU   Joel Przybilla
# 9  2000  10.0  ORL    Keyon Dooling
#
#     Year   Pk   Tm            Player
# 59  2001  1.0  WAS       Kwame Brown
# 60  2001  2.0  LAC    Tyson Chandler
# 61  2001  3.0  ATL         Pau Gasol
# 62  2001  4.0  CHI        Eddy Curry
# 63  2001  5.0  GSW  Jason Richardson
#
# 2000 2025 1578

# %%
from google.colab import files
files.download("nba_draft_2000_2025_clean.csv")
